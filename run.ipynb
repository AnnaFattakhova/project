# %%
# Запуск по шагам

# ШАГ 1
python run_1_parsing.py

# %%
# ШАГ 2
python run_2_topic_sentiment.py

# %%
# ШАГ 3
pip install spacy
python -m spacy download ru_core_news_sm

python run_3_aspect_analysis.py

# %%
# ШАГ 4
python run_4_visualization.py

# %%
# Юнит-тесты
pytest unit_tests/tests --color=no > unit_tests/results/result_all_tests.txt # — для запуска всех тестов сразу

# запуск по одному:
pytest unit_tests/tests/test_1.py --color=no > unit_tests/results/result_test_1.txt"
pytest unit_tests/tests/test_2.py --color=no > unit_tests/results/result_test_2.txt
pytest unit_tests/tests/test_3.py --color=no > unit_tests/results/result_test_3.txt
pytest unit_tests/tests/test_4.py --color=no > unit_tests/results/result_test_4.txt
